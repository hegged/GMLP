# %% [markdown]
# <H1>Assignment 2: Pandas</H1>
#
# This assignment is designed to introduce you to Pandas, a powerful library for data manipulation and analysis in Python. You'll learn how to create DataFrames, select and filter data, and perform basic data analysis tasks.
#
# <H2>Tools and Libraries</H2>
#
# Before starting, ensure you have the Pandas library installed in your Python environment:
# <ul>
#   <li>pip install pandas</li>
# </ul>

# %% [markdown]
# <b>Exercise 1:</b> Creating and Displaying a DataFrame
#
# <b>Task 1.1</b>
# Create a DataFrame df_students with the following data:
#
# <ol>
#   <li>Import the Pandas library.</li>
#   <li>Create a DataFrame df_students (see table).</li>
#     <li>Display the entire DataFrame.</li>
# </ol>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Name</th>
#       <th>Age</th>
#       <th>Grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Alice</td>
#       <td>20</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <td>Bob</td>
#       <td>22</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <td>Charlie</td>
#       <td>19</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <td>Diana</td>
#       <td>21</td>
#       <td>95</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>Task 1.2:</b> Selecting Data
#
# <ol>
#   <li>Select and print the 'Name' and 'Grade' columns from df_students.</li>
#   <li>Select and print the row for Charlie using iloc.</li>
# </ol>

# %% [markdown]
# <b>Task 1.3:</b> Filtering Data
#
# <ol>
#   <li>Filter and print the rows where 'Grade' is greater than 90.</li>
# </ol>

# %% [markdown]
# <b>Task 1.4:</b> Adding and Removing Columns
#
# <ol>
#   <li>Add a new column 'Passed' to df_students that marks 'True' if the 'Grade' is greater than or equal to 90, otherwise 'False'.</li>
#   <li>Remove the 'Age' column from df_students.</li>
#
# </ol>

# %% [markdown]
# <b>Task 1.5:</b> Basic Data Analysis
#
# <ol>
#   <li>Calculate and print the mean grade of the students.</li>
#   <li>Use .describe() to print overall dataframe statistics.</li>
# </ol>
