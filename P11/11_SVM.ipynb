# %% [markdown]
# <H1>Assignment: SVM</H1>
#
# <b>Objective:</b>
#
# This assignment focuses on exploring the impact of parameter search in Support Vector Machines. Using a synthetic moon dataset, students will evaluate how the regularization parameters, C and Gamma, affects model performance.
#
# <H2>Exercises:</H2>
#
# <b>Task 1.1: SVM</b>
# <ol>
#   <li>Implement a SVM classification model using scikit-learn's <code>SVC()</code>.
#   <li>Try different kernels (‘linear’, ‘rbf’) and appropriate hyperparameters of the kernel ('gamma') as well as the parameter C of the regularizer</li>
#   <li>Evaluate the model's performance using the <code>accuracy_score</code> of the classifier (see sklearn.metrics).</li>
#   <li>Plot the predicted outcomes for the test data.</li>
#   <li>What is the impact of the weight value for the regularizer ('C') and ('gamma')?
# </ol>
#
# <b>Task 1.2: Decision Surface and Support Vectors</b>
# <ol>
#   <li>Utilize scikit-learn's <code>DecisionBoundaryDisplay()</code> method to visualize the decision surface for levels: [-1,0,1].</li>
#   <li>Plot the training data and highlight the support vectors. How do you interpret the support vectors?</li>
# </ol>
#
# <b>Task 1.3: Grid Search for Parameters</b>
# <ol>
#   <li>Utilize scikit-learn's <code>GridSearchCV()</code> method to find an optimal set of hyperparameters.</li>
#   <li>Use for example: "C": [5,2,1,0.5,0.1], "gamma": np.logspace(-10, 10, 100) for the radial basis function kernel.</li>
#  <li>Print the optimal parameter values and compare the performance to your best model from Task 1.1</li>
# </ol>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_moons
import numpy as np
# stable outputs across different runs
seed = 42
np.random.seed(seed)

# function to visualize the 2d input data at
def plot_predictions(X,Y,title=None):
    plt.scatter(X[Y[:] == 1,0], X[Y[:] == 1,1], c='green', label='Positive')
    plt.scatter(X[Y[:] == 0,0], X[Y[:] == 0,1], c='red', label='Negative')
    plt.legend(loc='lower right')
    plt.title(title)
    plt.xlabel("feature 1")
    plt.ylabel("feature 2")
    plt.show()

size = 200
X, y = make_moons(size, noise=0.23, random_state=seed)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)


plot_predictions(X_train,y_train,title="Training Data")
plot_predictions(X_test,y_test,title="Test Data")
