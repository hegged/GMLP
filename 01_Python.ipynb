# %% [markdown]
# <H1>Assignment 1: Python</H1>
#
# The purpose of this assignment is to familiarize you with fundamental Python concepts that are essential for machine learning (ML). You will learn about basic data structures, such as lists and dictionaries, understand how to manipulate numerical data with arrays, access elements, and visualize data using basic plotting techniques.
# <H2>Tools and Libraries</H2>
# <ul>
#   <li>Python 3.x</li>
#   <li>NumPy</li>
#   <li>Matplotlib</li>
# </ul>
# Ensure you have these tools installed before starting the exercises.

# %% [markdown]
# <b>Exercise 1:</b> Working with Lists and Matrices
#
# <b>Task 1.1:</b> Create a Python list representing a vector and perform basic operations.
#
# <ol>
#   <li>Create a list vector_a with elements [2, 4, 6, 8].</li>
#   <li>Append an element 10 to vector_a.</li>
#   <li>Print the vector and the length of vector_a.</li>
# </ol>

# %%
import string

vector_a = [2, 4, 6, 8]
vector_a.append(10)
print("Vector:", vector_a)
print("Length of vector_a:", len(vector_a))

# %% [markdown]
# <b>Task 1.2:</b> Create a 2x3 matrix using nested lists and access elements.
# <ol>
#   <li>Create a matrix matrix_a with elements [[1, 2, 3], [4, 5, 6]].</li>
#   <li>Access the element in the second row and third column of matrix_a and print it.</li>
#   <li>Change the element in the first row and first column to 0 and print the updated matrix.</li>
# </ol>

# %%
matrix_a = [[1, 2, 3], [4, 5, 6]]
print("Element in second row, third column:", matrix_a[1][2])
matrix_a[0][0] = 0
print("Updated matrix_a:", matrix_a)

# %% [markdown]
# <b>Exercise 2:</b> Numerical Operations with NumPy
#
# <b>Task:</b> Perform basic numerical operations using NumPy arrays.
# <ol>
#   <li>Import the NumPy library.</li>
#   <li>Create a NumPy array array_a with elements [1, 2, 3, 4, 5].</li>
#   <li>Multiply array_a by 2 and print the result.</li>
#  <li>Compute the sum of all elements in array_a and print it.</li>
# </ol>

# %%
import numpy as np

array_a = np.array([1, 2, 3, 4, 5])
result = array_a * 2
print("Array multiplied by 2:", result)
sum_array_a = np.sum(array_a)
print("Sum of all elements in array_a:", sum_array_a)

# %% [markdown]
# <b>Exercise 3:</b> Basic Data Visualization with Matplotlib
#
# <b>Task:</b> Plot a simple line graph and customize it.
#
# <ol>
#   <li>Import the Matplotlib library.</li>
#   <li>Create two lists: x = [1, 2, 3, 4, 5] and y = [2, 3, 5, 7, 11].</li>
#   <li>Using Matplotlib, plot y versus x as a line graph.</li>
#  <li>Add a title "Sample Line Graph" and label axes as "X Axis" and "Y Axis".
# Display the plot.</li>
# </ol>

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.title("Sample Line Graph")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

# %% [markdown]
# <b>Exercise 4:</b> Word Frequency Counter
#
# <b>Task:</b>
# Write a function word_frequency(text) that takes a string text as input and returns a dictionary where the keys are words and the values are the number of times each word appears in the text.
# Words should be treated as case-insensitive (e.g., "The" and "the" are considered the same word).
# Exclude punctuation from consideration (e.g., "hello," and "hello" are the same word).

# %% [markdown]
# Use the text: "To be, or not to be, that is the question:
# Whether it is nobler in the mind to suffer
# The slings and arrows of outrageous fortune,
# Or to take arms against a sea of troubles
# And by opposing end them."

# %% [markdown]
# <b>Guidelines:</b>
# Consider using Python's built-in str methods, such as .lower() for case normalization and .translate() for punctuation removal.
# The collections module, specifically Counter, can be very helpful for the word frequency counter task.
# For cleaning the text, you may find the string module useful, especially string.punctuation for identifying characters to exclude.

# %%
def word_frequency(text):
    import string
    from collections import Counter

    # Normalize the text to lowercase
    text = text.lower()

    # Remove punctuation
    translator = str.maketrans('', '', string.punctuation)
    cleaned_text = text.translate(translator)

    # Split the cleaned text into words
    words = cleaned_text.split()

    # Count the frequency of each word
    frequency = Counter(words)

    return dict(frequency)
word_frequency("""To be, or not to be, that is the question:
Whether it is nobler in the mind to suffer The slings and arrows of outrageous fortune,
Or to take arms against a sea of troubles And by opposing end them.""")
# Out:
# {'to': 4,
#  'be': 2,
#  'or': 2,
#  'not': 1,
#  'that': 1,
#  'is': 2,
#  'the': 3,
#  'question': 1,
#  'whether': 1,
#  'it': 1,
#  'nobler': 1,
#  'in': 1,
#  'mind': 1,
#  'suffer': 1,
#  'slings': 1,
#  'and': 2,
#  'arrows': 1,
#  'of': 2,
#  'outrageous': 1,
#  'fortune': 1,
#  'take': 1,
#  'arms': 1,
#  'against': 1,
#  'a': 1,
#  'sea': 1,
#  'troubles': 1,
#  'by': 1,
#  'opposing': 1,
#  'end': 1,
#  'them': 1}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 word_frequency("""To be, or not to be, that is the question: Whether it is nobler in the mind to suffer The slings and arrows of outrageous fortune, Or to take arms against a sea of troubles And by opposing end them.""")
#
# NameError: name 'word_frequency' is not defined
